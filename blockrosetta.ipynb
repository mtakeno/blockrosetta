# %%
# A python snippet to test the display of csv files and Jupyter notebooks in Confluence

import pandas as pd

df1 = pd.read_csv("blocktable.csv")
df1['bcm_id'] = df1.bcm_id.astype(object)
df2 = df1.set_index("specimen_id")

# %%
df2
# Out:
#              lims_specimen_id                                       lims_name  \
# specimen_id
# 17795_1R            665666369                          Slc/Ai162-383766.01.02
# 17358_1R            665661675              Slc/Ai148/H2B-mCherry-383765.01.02
# 343033_1L           657861895            Slc17a7-IRES2-Cre;Ai148-343033.01.01
# 17021_1R            656634693             Dlx5;Slc17a7-Cre;Ai148-371837.01.02
# 247488_9L           603924974                            C57BL/6-247488.09.01
# 239849_7R           603908037            Camk2a-tTA/tetO-GCaMP6s-239849.07.01
# 247488_8R           661511423                            C57BL/6-247488.08.02
# 247488_7L           603924963                            C57BL/6-247488.07.01
# 295434_5LC          594089217                           C57BL/6J-295434.05.01
# 284678_2RB1         603924995  Scnn1a-Tg3-Cre;Rosa26-ZtTA;Ai133-284678.02.01
# 295434_4LB          603907295                          C57BL/6J-295434.04.01
#
# ...
